# %% [markdown]
# In this project, we collected data from various sources, cleaned, annotated and categorized them. In this notebook, we will conduct an exploratory data analysis of the collected text data.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Location of the cleaned text data
filepath = "../../data/data-final-cleaned.csv"
df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#               Source Category  \
# 0  Copperbelt Energy   career
# 1  Copperbelt Energy   career
# 2  Copperbelt Energy   career
# 3  Copperbelt Energy   career
# 4  Copperbelt Energy   career
#
#                                             Headline  \
# 0   ['CEC', 'Career', 'Opportunity', 'GDP', 'Legal']
# 1  ['CEC', 'Career', 'Opportunity', 'Assurance', ...
# 2  ['CEC', 'Career', 'Opportunity', 'Internal', '...
# 3  ['CEC', 'Career', 'Opportunity', 'Engineer', '...
# 4  ['CEC', 'Career', 'Opportunity', 'Mechanic', '...
#
#                                          Description  \
# 0  ['currently', 'career', 'opportunity', 'follow...
# 1  ['currently', 'career', 'opportunity', 'follow...
# 2  ['currently', 'career', 'opportunity', 'follow...
# 3  ['currently', 'career', 'opportunity', 'follow...
# 4  ['currently', 'career', 'opportunity', 'follow...
#
#                                               Link                       Date  \
# 0  https://cecinvestor.com/search/kitwe/feed/rss2/  2024-11-20 16:31:18+00:00
# 1  https://cecinvestor.com/search/kitwe/feed/rss2/  2024-11-20 15:15:28+00:00
# 2  https://cecinvestor.com/search/kitwe/feed/rss2/  2024-11-20 15:14:39+00:00
# 3  https://cecinvestor.com/search/kitwe/feed/rss2/  2024-11-20 15:13:41+00:00
# 4  https://cecinvestor.com/search/kitwe/feed/rss2/  2024-11-20 15:13:05+00:00
#
#               Author  Target
# 0  Lovejoy Musundire       0
# 1  Lovejoy Musundire       0
# 2  Lovejoy Musundire       0
# 3  Lovejoy Musundire       0
# 4  Lovejoy Musundire       0

# %%
df.shape
# Out:
# (14282, 8)

# %%
source_count = df['Source'].value_counts()
print(source_count)
# Out:
# Source
# Lusaka Times               6479
# Lusaka Voice               1745
# Daily Nations Zambia       1361
# Zambia Eye                 1022
# Kitwe Online                889
# Mwebantu                    711
# Zambia Monitor              627
# Copperbelt Energy           445
# Zambian Eye                 300
# Daily Revelation Zambia     202
# Zambia365                   130
# Zambia Reports              119
# News Invasion 24             84
# Lusaka Star                  67
# ZNBC                         64
# Flava FM                     14
# DailyMail                    10
# Tech Africa News              7
# Christian Voice               4
# Daily Mail Zambia             2
# Name: count, dtype: int64

# %%
source_count.plot(kind="bar", figsize=(8,6))
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
Most of the news have been obtained from the K
