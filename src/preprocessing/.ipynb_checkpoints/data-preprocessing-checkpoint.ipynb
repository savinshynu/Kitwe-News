# %% [markdown]
# We have collected a bunch of news data using RSS feeds. Now we will take a look at the data and do some cleaning with pandas and spacy. This will include the
# 1. Tokenization
# 2. lowercasing
# 3. Converting date and time to a standard format
# 4. lemmatization
# 5. removing duplicate entries
# 6. removing unnecessary paranthesis

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/raw-new.csv')
df.head(5)
# Out:
#          cd ..Source                 Category  \
# 0  Copperbelt Energy  Careers,Current Careers
# 1  Copperbelt Energy  Careers,Current Careers
# 2  Copperbelt Energy  Careers,Current Careers
# 3  Copperbelt Energy  Careers,Current Careers
# 4  Copperbelt Energy  Careers,Current Careers
#
#                                             Headline  \
# 0                CEC Career Opportunity: GDP – Legal
# 1  CEC Career Opportunity: Assurance Specialist –...
# 2  CEC Career Opportunity: Internal Auditor –  In...
# 3      CEC Career Opportunity: Engineer – Protection
# 4                CEC Career Opportunity: Mechanic II
#
#                                               Link  \
# 0  https://cecinvestor.com/search/kitwe/feed/rss2/
# 1  https://cecinvestor.com/search/kitwe/feed/rss2/
# 2  https://cecinvestor.com/search/kitwe/feed/rss2/
# 3  https://cecinvestor.com/search/kitwe/feed/rss2/
# 4  https://cecinvestor.com/search/kitwe/feed/rss2/
#
# ...

# %%
df.shape
# Out:
# (2226, 7)

# %%
df.duplicate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_17044/2256583062.py in ?()
# ----> 1 df.duplicate()
#
# ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'
